# %% [markdown]
# # Data manipulation in R
#
# This notebook imports the `Data/Organ.csv` file, and computes the Ising number

# %%
organ <- read.csv("../Data/Organ.csv")

# %%
summary(organ)
# Out:
#    flueDepth           frequency      cutUpHeight       diameterToe
#  Min.   :0.0003500   Min.   : 98.0   Min.   :0.01000   Min.   :0.0070
#  1st Qu.:0.0008750   1st Qu.:103.8   1st Qu.:0.01200   1st Qu.:0.0070
#  Median :0.0010600   Median :116.5   Median :0.01400   Median :0.0080
#  Mean   :0.0009983   Mean   :127.0   Mean   :0.01382   Mean   :0.2197
#  3rd Qu.:0.0012000   3rd Qu.:146.8   3rd Qu.:0.01570   3rd Qu.:0.0085
#  Max.   :0.0013500   Max.   :196.0   Max.   :0.01700   Max.   :7.0000
#  acousticIntensity    partial1        partial2        partial3
#  Min.   : 61.50    Min.   : 0.00   Min.   : 0.00   Min.   : 0.00
#  1st Qu.: 65.60    1st Qu.:70.00   1st Qu.: 5.00   1st Qu.:63.00
#  Median : 71.00    Median :99.00   Median :67.00   Median :78.00
#  Mean   : 73.32    Mean   :81.39   Mean   :54.03   Mean   :70.48
#  3rd Qu.: 79.00    3rd Qu.:99.00   3rd Qu.:97.00   3rd Qu.:87.00
#  Max.   :111.00    Max.   :99.00   Max.   :99.00   Max.   :99.00
# ...

# %%
attach(organ)

# %%
png("larger_plot.png", width = 1200, height = 800)
plot(organ)
dev.off()
# Out:
# pdf
#   2

# %%
str(organ)
# Out:
# 'data.frame':	33 obs. of  13 variables:
#  $ flueDepth        : num  0.00035 0.00035 0.00106 0.00106 0.0006 0.0011 0.0011 0.0011 0.0011 0.0011 ...
#  $ frequency        : num  196 196 147 139 175 ...
#  $ cutUpHeight      : num  0.0105 0.0105 0.012 0.012 0.01 0.01 0.017 0.017 0.017 0.017 ...
#  $ diameterToe      : num  0.007 0.0085 0.007 0.0085 0.0072 0.011 0.007 0.008 0.009 0.01 ...
#  $ acousticIntensity: num  73 90 65 86 87 111 66 68 79 84 ...
#  $ partial1         : num  99 70 91 11 44 34 95 99 32 34 ...
#  $ partial2         : num  61 99 43 0 0 99 99 97 99 99 ...
#  $ partial3         : num  87 73 99 99 99 17 55 97 21 42 ...
#  $ partial4         : num  37 18 52 3 13 11 42 81 29 0 ...
#  $ partial5         : num  44 13 69 0 52 59 40 64 0 0 ...
#  $ partial6         : num  0 0 40 0 33 28 21 45 6 23 ...
#  $ partial7         : num  5 5 50 0 0 0 17 30 9 11 ...
#  $ partial8         : num  0 0 19 0 25 32 0 12 0 9 ...

# %%
organ$areaToe <- pi * ((organ$diameterToe/2)^2)

# %%
str(organ)
# Out:
# 'data.frame':	33 obs. of  14 variables:
#  $ flueDepth        : num  0.00035 0.00035 0.00106 0.00106 0.0006 0.0011 0.0011 0.0011 0.0011 0.0011 ...
#  $ frequency        : num  196 196 147 139 175 ...
#  $ cutUpHeight      : num  0.0105 0.0105 0.012 0.012 0.01 0.01 0.017 0.017 0.017 0.017 ...
#  $ diameterToe      : num  0.007 0.0085 0.007 0.0085 0.0072 0.011 0.007 0.008 0.009 0.01 ...
#  $ acousticIntensity: num  73 90 65 86 87 111 66 68 79 84 ...
#  $ partial1         : num  99 70 91 11 44 34 95 99 32 34 ...
#  $ partial2         : num  61 99 43 0 0 99 99 97 99 99 ...
#  $ partial3         : num  87 73 99 99 99 17 55 97 21 42 ...
#  $ partial4         : num  37 18 52 3 13 11 42 81 29 0 ...
#  $ partial5         : num  44 13 69 0 52 59 40 64 0 0 ...
#  $ partial6         : num  0 0 40 0 33 28 21 45 6 23 ...
#  $ partial7         : num  5 5 50 0 0 0 17 30 9 11 ...
#  $ partial8         : num  0 0 19 0 25 32 0 12 0 9 ...
# ...

# %%
plot(organ)
# Out:
# plot without title

# %%
organ$Ising <- sqrt((((0.77 * 2) * organ$flueDepth)/(1.185 * (organ$cutUpHeight)^3))/organ$frequency)

# %%
str(organ)
# Out:
# 'data.frame':	33 obs. of  15 variables:
#  $ flueDepth        : num  0.00035 0.00035 0.00106 0.00106 0.0006 0.0011 0.0011 0.0011 0.0011 0.0011 ...
#  $ frequency        : num  196 196 147 139 175 ...
#  $ cutUpHeight      : num  0.0105 0.0105 0.012 0.012 0.01 0.01 0.017 0.017 0.017 0.017 ...
#  $ diameterToe      : num  0.007 0.0085 0.007 0.0085 0.0072 0.011 0.007 0.008 0.009 0.01 ...
#  $ acousticIntensity: num  73 90 65 86 87 111 66 68 79 84 ...
#  $ partial1         : num  99 70 91 11 44 34 95 99 32 34 ...
#  $ partial2         : num  61 99 43 0 0 99 99 97 99 99 ...
#  $ partial3         : num  87 73 99 99 99 17 55 97 21 42 ...
#  $ partial4         : num  37 18 52 3 13 11 42 81 29 0 ...
#  $ partial5         : num  44 13 69 0 52 59 40 64 0 0 ...
#  $ partial6         : num  0 0 40 0 33 28 21 45 6 23 ...
#  $ partial7         : num  5 5 50 0 0 0 17 30 9 11 ...
#  $ partial8         : num  0 0 19 0 25 32 0 12 0 9 ...
# ...

# %%
plot(organ)
# Out:
# plot without title
